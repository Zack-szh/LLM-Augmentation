# %% [markdown]
# # Format
#
# - Example Key: "https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2023-01-09/2023-02-10?adjusted=true&sort=asc&apiKey=AId2XrKr6zKDLWmwYsbnAaEf4EoHvM5l"
#
# {
#     "ticker": "AAPL",
#     "queryCount": 6,
#     "resultsCount": 6,
#     "adjusted": true,
#     "results": [
#         {
#             "v": 61791843,
#             "vw": 222.8069,
#             "o": 220.965,
#             "c": 222.91,
#             "h": 225.35,
#             "l": 220.27,
#             "t": 1730433600000,
#             "n": 859056
#         },
#         {
#             "v": 40921729,
#             "vw": 221.7547,
#             "o": 220.99,
#             "c": 222.01,
#             "h": 222.79,
#             "l": 219.71,
#             "t": 1730696400000,
#             "n": 647102
#         },
#         {
#             "v": 27254038,
#             "vw": 223.094,
#             "o": 221.795,
#             "c": 223.45,
#             "h": 223.95,
#             "l": 221.14,
#             "t": 1730782800000,
#             "n": 501988
#         },
#         {
#             "v": 51811157,
#             "vw": 223.8587,
#             "o": 222.61,
#             "c": 222.72,
#             "h": 226.065,
#             "l": 221.19,
#             "t": 1730869200000,
#             "n": 796494
#         },
#         {
#             "v": 40121817,
#             "vw": 226.7564,
#             "o": 224.625,
#             "c": 227.48,
#             "h": 227.875,
#             "l": 224.57,
#             "t": 1730955600000,
#             "n": 623113
#         },
#         {
#             "v": 36726907,
#             "vw": 227.2234,
#             "o": 227.17,
#             "c": 226.96,
#             "h": 228.66,
#             "l": 226.405,
#             "t": 1731042000000,
#             "n": 541011
#         }
#     ],
#     "status": "DELAYED",
#     "request_id": "4697afe4ba1c3d0eecc9a6ebebdd9b89",
#     "count": 6
# }
